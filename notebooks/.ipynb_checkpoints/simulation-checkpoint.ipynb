# %%
from simulation.simulation import Simulation
from simulation.demand_engine import calculate_daily_orders
import simulation.simulation_config as config

sim = Simulation()

sim.load_master_data()

sim.initialize_inventory()

run_simulation(sim)

sim.export_tables()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from simulation.simulation import Simulation
#       2 from simulation.demand_engine import calculate_daily_orders
#       3 import simulation.simulation_config as config
#
# ModuleNotFoundError: No module named 'simulation'
