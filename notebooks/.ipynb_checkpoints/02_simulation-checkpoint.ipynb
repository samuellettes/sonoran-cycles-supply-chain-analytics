# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
from datetime import datetime

from simulation.simulation import Simulation
from simulation.demand_engine import preview_day
import simulation.simulation_config as config

# %%
from simulation.simulation import Simulation
from simulation.customer_engine import add_customer_order_weights, select_dealer, select_dtc_customer
from simulation.product_engine import choose_product

# %%
sim = Simulation()
sim.load_master_data()
sim.initialize_inventory()

sim.customers = add_customer_order_weights(sim.customers)

# %%
from datetime import datetime
import pandas as pd

from simulation.simulation import Simulation
from simulation.customer_engine import add_customer_order_weights
from simulation.order_generator import (
    generate_dealer_order,
    generate_dtc_order,
    generate_daily_orders,
)

# %%
sim = Simulation()
sim.load_master_data()
sim.initialize_inventory()

sim.customers = add_customer_order_weights(sim.customers)

# %%
dealer_header, dealer_lines = generate_dealer_order(
    sim,
    datetime(2023, 5, 15),
)

dealer_header
# Out:
# {'sales_order_id': 'SO100000',
#  'order_date': '2023-05-15',
#  'customer_id': 'C0015',
#  'customer_name': 'Sierra Cycle Works',
#  'sales_channel': 'Dealer',
#  'order_status': 'Booked',
#  'payment_terms': 'Net 30',
#  'warehouse': 'Phoenix Distribution Center',
#  'order_total': 42895.32}

# %%
pd.DataFrame(dealer_lines)
# Out:
#   sales_order_id  line_number  product_id             sku model_name  \
# 0       SO100000            1        1109  SON-ROM-C-L-IR     Romero
# 1       SO100000            2        1105  SON-ROM-C-M-SS     Romero
# 2       SO100000            3        1076  SON-SAB-C-M-GR     Sabino
# 3       SO100000            4        1111  SON-ROM-C-L-SS     Romero
# 4       SO100000            5        1084  SON-SAB-C-L-SK     Sabino
#
#            category size     color  requested_qty  fulfilled_qty  ...  \
# 0  Aggressive Trail    L  Ironwood              2              2  ...
# 1  Aggressive Trail    M    Sunset              4              4  ...
# 2             Trail    M   Granite              1              1  ...
# 3  Aggressive Trail    L    Sunset              2              2  ...
# 4             Trail    L       Sky              5              5  ...
#
#    unit_msrp  discount_pct  unit_price  extended_price  fulfilled_revenue  \
# 0     5199.0          0.38     3223.38         6446.76            6446.76
# 1     5199.0          0.38     3223.38        12893.52           12893.52
# 2     4599.0          0.38     2851.38         2851.38            2851.38
# 3     5199.0          0.38     3223.38         6446.76            6446.76
# 4     4599.0          0.38     2851.38        14256.90           14256.90
#
#    unit_cost  extended_cost  fulfilled_cost  gross_profit  \
# 0    3015.42        6030.84         6030.84        415.92
# 1    3015.42       12061.68        12061.68        831.84
# 2    2575.44        2575.44         2575.44        275.94
# 3    3015.42        6030.84         6030.84        415.92
# 4    2575.44       12877.20        12877.20       1379.70
#
#    fulfilled_gross_profit
# 0                  415.92
# 1                  831.84
# 2                  275.94
# 3                  415.92
# 4                 1379.70
#
# [5 rows x 22 columns]

# %%
dtc_header, dtc_lines = generate_dtc_order(
    sim,
    datetime(2023, 5, 15),
)

dtc_header
# Out:
# {'sales_order_id': 'SO100001',
#  'order_date': '2023-05-15',
#  'customer_id': 'C0001',
#  'customer_name': 'Sonoran Cycles Online',
#  'sales_channel': 'DTC',
#  'order_status': 'Booked',
#  'payment_terms': 'Credit Card',
#  'warehouse': 'Phoenix Distribution Center',
#  'order_total': 4599.0}

# %%
pd.DataFrame(dtc_lines)
# Out:
#   sales_order_id  line_number  product_id             sku model_name category  \
# 0       SO100001            1        1074  SON-SAB-C-M-SG     Sabino    Trail
#
#   size    color  requested_qty  fulfilled_qty  ...  unit_msrp  discount_pct  \
# 0    M  Saguaro              1              1  ...     4599.0           0.0
#
#    unit_price  extended_price  fulfilled_revenue  unit_cost  extended_cost  \
# 0      4599.0          4599.0             4599.0    2575.44        2575.44
#
#    fulfilled_cost  gross_profit  fulfilled_gross_profit
# 0         2575.44       2023.56                 2023.56
#
# [1 rows x 22 columns]

# %%
daily_summary = generate_daily_orders(
    sim,
    datetime(2023, 5, 15),
    "Sunny",
)

daily_summary
# Out:
# {'date': '2023-05-15',
#  'weather': 'Sunny',
#  'dealer_orders': 28,
#  'dtc_orders': 13,
#  'total_orders': 41}

# %%
pd.DataFrame(sim.sales_orders).head()
# Out:
#   sales_order_id  order_date customer_id          customer_name sales_channel  \
# 0       SO100000  2023-05-15       C0015     Sierra Cycle Works        Dealer
# 1       SO100001  2023-05-15       C0001  Sonoran Cycles Online           DTC
# 2       SO100002  2023-05-15       C0028      Windy City Cycles        Dealer
# 3       SO100003  2023-05-15       C0005    Mesa Mountain Bikes        Dealer
# 4       SO100004  2023-05-15       C0020        Alpine Ride Co.        Dealer
#
#   order_status payment_terms                    warehouse  order_total
# 0       Booked        Net 30  Phoenix Distribution Center     42895.32
# 1       Booked   Credit Card  Phoenix Distribution Center      4599.00
# 2       Booked        Net 30  Phoenix Distribution Center     34768.50
# 3       Booked        Net 30  Phoenix Distribution Center     17154.80
# 4       Booked        Net 30  Phoenix Distribution Center     25847.18

# %%
pd.DataFrame(sim.sales_order_lines).head()
# Out:
#   sales_order_id  line_number  product_id             sku model_name  \
# 0       SO100000            1        1109  SON-ROM-C-L-IR     Romero
# 1       SO100000            2        1105  SON-ROM-C-M-SS     Romero
# 2       SO100000            3        1076  SON-SAB-C-M-GR     Sabino
# 3       SO100000            4        1111  SON-ROM-C-L-SS     Romero
# 4       SO100000            5        1084  SON-SAB-C-L-SK     Sabino
#
#            category size     color  requested_qty  fulfilled_qty  ...  \
# 0  Aggressive Trail    L  Ironwood              2              2  ...
# 1  Aggressive Trail    M    Sunset              4              4  ...
# 2             Trail    M   Granite              1              1  ...
# 3  Aggressive Trail    L    Sunset              2              2  ...
# 4             Trail    L       Sky              5              5  ...
#
#    unit_msrp  discount_pct  unit_price  extended_price  fulfilled_revenue  \
# 0     5199.0          0.38     3223.38         6446.76            6446.76
# 1     5199.0          0.38     3223.38        12893.52           12893.52
# 2     4599.0          0.38     2851.38         2851.38            2851.38
# 3     5199.0          0.38     3223.38         6446.76            6446.76
# 4     4599.0          0.38     2851.38        14256.90           14256.90
#
#    unit_cost  extended_cost  fulfilled_cost  gross_profit  \
# 0    3015.42        6030.84         6030.84        415.92
# 1    3015.42       12061.68        12061.68        831.84
# 2    2575.44        2575.44         2575.44        275.94
# 3    3015.42        6030.84         6030.84        415.92
# 4    2575.44       12877.20        12877.20       1379.70
#
#    fulfilled_gross_profit
# 0                  415.92
# 1                  831.84
# 2                  275.94
# 3                  415.92
# 4                 1379.70
#
# [5 rows x 22 columns]

# %%
print("Sales orders:", len(sim.sales_orders))
print("Sales order lines:", len(sim.sales_order_lines))
# Out:
# Sales orders: 43
# Sales order lines: 123

# %%
import pandas as pd

from simulation.simulation import Simulation
from simulation.simulation_runner import run_sales_simulation

# %%
sim = Simulation()
sim.load_master_data()
sim.initialize_inventory()

# %%
daily_summary = run_sales_simulation(
    sim,
    start_date="2023-05-01",
    end_date="2023-05-07",
)

# %%
pd.DataFrame(daily_summary)
# Out:
#          date weather  dealer_orders  dtc_orders  total_orders  \
# 0  2023-05-01   Sunny             27          12            39
# 1  2023-05-02   Sunny             29          14            43
# 2  2023-05-03   Sunny             26          14            40
# 3  2023-05-04   Sunny             30          13            43
# 4  2023-05-05   Sunny             27          17            44
# 5  2023-05-06   Sunny              8          17            25
# 6  2023-05-07   Sunny              2          16            18
#
#    total_on_hand_units  total_available_units  out_of_stock_skus
# 0                 8138                   8138                  0
# 1                 7866                   7866                  0
# 2                 7623                   7623                  0
# 3                 7332                   7332                  0
# 4                 7073                   7073                  0
# 5                 6972                   6972                  0
# 6                 6942                   6942                  0

# %%
pd.DataFrame(sim.sales_orders).head()
# Out:
#   sales_order_id  order_date customer_id       customer_name sales_channel  \
# 0       SO100000  2023-05-01       C0008  Sedona Ride Center        Dealer
# 1       SO100001  2023-05-01       C0004    Sonoran Bike Co.        Dealer
# 2       SO100002  2023-05-01       C0033   Appalachian Bikes        Dealer
# 3       SO100003  2023-05-01       C0004    Sonoran Bike Co.        Dealer
# 4       SO100004  2023-05-01       C0021   Rocky Peak Cycles        Dealer
#
#   order_status payment_terms                    warehouse  order_total
# 0       Booked        Net 30  Phoenix Distribution Center     15745.52
# 1       Booked        Net 30  Phoenix Distribution Center     55294.08
# 2       Booked        Net 30  Phoenix Distribution Center     25415.04
# 3       Booked        Net 30  Phoenix Distribution Center     26779.04
# 4       Booked        Net 30  Phoenix Distribution Center     22614.80

# %%
pd.DataFrame(sim.sales_order_lines).head()
# Out:
#   sales_order_id  line_number  product_id             sku  model_name  \
# 0       SO100000            1        1105  SON-ROM-C-M-SS      Romero
# 1       SO100000            2        1163  SON-SKY-C-M-IR  Sky Island
# 2       SO100001            1        1134  SON-ORA-C-M-SG      Oracle
# 3       SO100001            2        1141  SON-ORA-C-L-SS      Oracle
# 4       SO100001            3        1105  SON-ROM-C-M-SS      Romero
#
#            category size     color  requested_qty  fulfilled_qty  ...  \
# 0  Aggressive Trail    M    Sunset              2              2  ...
# 1              eMTB    M  Ironwood              2              2  ...
# 2            Enduro    M   Saguaro              3              3  ...
# 3            Enduro    L    Sunset              3              3  ...
# 4  Aggressive Trail    M    Sunset              5              5  ...
#
#    unit_msrp  discount_pct  unit_price  extended_price  fulfilled_revenue  \
# 0     5199.0          0.38     3223.38         6446.76            6446.76
# 1     7499.0          0.38     4649.38         9298.76            9298.76
# 2     6199.0          0.38     3843.38        11530.14           11530.14
# 3     6199.0          0.38     3843.38        11530.14           11530.14
# 4     5199.0          0.38     3223.38        16116.90           16116.90
#
#    unit_cost  extended_cost  fulfilled_cost  gross_profit  \
# 0    3015.42        6030.84         6030.84        415.92
# 1    4799.36        9598.72         9598.72       -299.96
# 2    3719.40       11158.20        11158.20        371.94
# 3    3719.40       11158.20        11158.20        371.94
# 4    3015.42       15077.10        15077.10       1039.80
#
#    fulfilled_gross_profit
# 0                  415.92
# 1                 -299.96
# 2                  371.94
# 3                  371.94
# 4                 1039.80
#
# [5 rows x 22 columns]

# %%
print("Sales orders:", len(sim.sales_orders))
print("Sales order lines:", len(sim.sales_order_lines))
# Out:
# Sales orders: 252
# Sales order lines: 724

# %%
orders_df = pd.DataFrame(sim.sales_orders)
lines_df = pd.DataFrame(sim.sales_order_lines)

header_totals = orders_df.set_index("sales_order_id")["order_total"]
line_totals = lines_df.groupby("sales_order_id")["extended_price"].sum()

max_difference = (
    header_totals.round(2) - line_totals.round(2)
).abs().max()

max_difference
# Out:
# 0.0

# %%
sim = Simulation()
sim.load_master_data()
sim.initialize_inventory()

daily_summary = run_sales_simulation(
    sim,
    start_date="2023-01-01",
    end_date="2023-12-31",
)

print("Sales orders:", len(sim.sales_orders))
print("Sales order lines:", len(sim.sales_order_lines))

# %%
sim.export_tables()

# %%
orders_df = pd.DataFrame(sim.sales_orders)
lines_df = pd.DataFrame(sim.sales_order_lines)
daily_df = pd.DataFrame(sim.daily_order_summary)

print("Sales orders:", len(orders_df))
print("Sales order lines:", len(lines_df))
print("Daily summaries:", len(daily_df))
print("Total revenue:", round(orders_df["order_total"].sum(), 2))
print("Total units:", lines_df["requested_qty"].sum())

# %%
header_totals = orders_df.set_index("sales_order_id")["order_total"]
line_totals = lines_df.groupby("sales_order_id")["extended_price"].sum()

max_difference = (
    header_totals.round(2) - line_totals.round(2)
).abs().max()

max_difference

# %%
orders_df["sales_channel"].value_counts()

# %%
orders_df.groupby("sales_channel")["order_total"].sum().round(2)

# %%
lines_df.groupby("model_name")["requested_qty"].sum().sort_values(ascending=False)

# %%
orders_df["order_date"] = pd.to_datetime(orders_df["order_date"])
orders_df["month"] = orders_df["order_date"].dt.month

monthly_orders = (
    orders_df
    .groupby("month")["sales_order_id"]
    .count()
    .reset_index(name="order_count")
)

monthly_orders

# %%
import pandas as pd

from simulation.simulation import Simulation
from simulation.simulation_runner import run_sales_simulation

# %%
sim = Simulation()
sim.load_master_data()
sim.initialize_inventory()

daily_summary = run_sales_simulation(
    sim,
    start_date="2023-05-01",
    end_date="2023-05-07",
)

# %%
pd.DataFrame(daily_summary)

# %%
lines_df = pd.DataFrame(sim.sales_order_lines)

lines_df[
    [
        "sales_order_id",
        "product_id",
        "model_name",
        "requested_qty",
        "fulfilled_qty",
        "backordered_qty",
        "fill_rate",
        "extended_price",
        "fulfilled_revenue",
    ]
].head()

# %%
inventory_history_df = pd.DataFrame(sim.inventory_history)

inventory_history_df.head()

# %%
print("Sales orders:", len(sim.sales_orders))
print("Sales order lines:", len(sim.sales_order_lines))
print("Inventory history rows:", len(sim.inventory_history))

# %%
len(sim.products) * 7

# %%
len(sim.inventory_history) == len(sim.products) * 7

# %%
lines_df = pd.DataFrame(sim.sales_order_lines)

initial_inventory_units = len(sim.products) * 40
fulfilled_units = lines_df["fulfilled_qty"].sum()
ending_inventory_units = sim.inventory["on_hand"].sum()

inventory_difference = (
    initial_inventory_units
    - fulfilled_units
    - ending_inventory_units
)

inventory_difference

# %%
sim = Simulation()
sim.load_master_data()
sim.initialize_inventory()

daily_summary = run_sales_simulation(
    sim,
    start_date="2023-01-01",
    end_date="2023-12-31",
)

orders_df = pd.DataFrame(sim.sales_orders)
lines_df = pd.DataFrame(sim.sales_order_lines)
daily_df = pd.DataFrame(sim.daily_order_summary)

print("Sales orders:", len(orders_df))
print("Sales order lines:", len(lines_df))
print("Requested units:", lines_df["requested_qty"].sum())
print("Fulfilled units:", lines_df["fulfilled_qty"].sum())
print("Backordered units:", lines_df["backordered_qty"].sum())
print("Ending inventory:", sim.inventory["on_hand"].sum())
print("Out of stock SKUs:", (sim.inventory["available"] <= 0).sum())

# %%
import pandas as pd

from simulation.simulation import Simulation
from simulation.simulation_runner import run_sales_simulation

# %%
sim = Simulation()
sim.load_master_data()
sim.initialize_inventory()

daily_summary = run_sales_simulation(
    sim,
    start_date="2023-01-01",
    end_date="2023-01-31",
)

# %%
pd.DataFrame(daily_summary).head()

# %%
po_df = pd.DataFrame(sim.purchase_orders)

po_df.head()

# %%
po_df = pd.DataFrame(sim.purchase_orders)

po_df.head()

# %%
po_df["po_status"].value_counts()
