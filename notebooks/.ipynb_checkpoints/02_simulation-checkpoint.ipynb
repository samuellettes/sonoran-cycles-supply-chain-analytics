# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
from datetime import datetime

from simulation.simulation import Simulation
from simulation.demand_engine import preview_day
import simulation.simulation_config as config

# %%
from simulation.simulation import Simulation
from simulation.customer_engine import add_customer_order_weights, select_dealer, select_dtc_customer
from simulation.product_engine import choose_product

# %%
sim = Simulation()
sim.load_master_data()
sim.initialize_inventory()

sim.customers = add_customer_order_weights(sim.customers)

# %%
for _ in range(10):
    dealer = select_dealer(sim)
    product = choose_product(sim, dealer["dealer_profile"])

    print(
        dealer["customer_name"],
        "|",
        dealer["dealer_profile"],
        "|",
        product["model_name"],
        product["size"],
        product["color"]
    )
# Out:
# Blue Ridge Cycles | Trail Shop | Sabino S Sky
# Southern Singletrack | Generalist | Sabino L Coyote
# Evergreen Cyclery | XC Specialist | Rincon S Sky
# Sonoran Bike Co. | Aggressive MTB | Romero M Sunset
# Pisgah Bike Co. | Aggressive MTB | Oracle XL Sky
# Blue Ridge Cycles | Trail Shop | Sabino XL Sky
# Front Range Cyclery | Trail Shop | Romero S Granite
# Redwood Ride Shop | Generalist | Catalina L Sky
# Sedona Ride Center | Premium Dealer | Sky Island L Saguaro
# Windy City Cycles | Generalist | Catalina M Coyote
