# %%
"""
=========================================================
Sonoran Cycles Demand Planning Simulation
Configuration File
=========================================================

This file contains all business assumptions used by the
simulation. Adjust values here to change simulation behavior
without modifying the simulation engine.
"""

# =========================================================
# SIMULATION DATES
# =========================================================

START_DATE = "2021-01-01"
END_DATE = "2025-12-31"

# =========================================================
# DAILY BASE DEMAND
# =========================================================

BASE_DEALER_ORDERS = 18
BASE_DTC_ORDERS = 10

# =========================================================
# MONTHLY SEASONALITY
# =========================================================

MONTHLY_MULTIPLIER = {
    1: 0.55,
    2: 0.65,
    3: 0.90,
    4: 1.20,
    5: 1.35,
    6: 1.30,
    7: 1.15,
    8: 1.00,
    9: 0.90,
    10: 0.75,
    11: 0.80,
    12: 0.60
}

# =========================================================
# DEALER WEEKDAY MULTIPLIERS
# =========================================================

DEALER_WEEKDAY = {
    0: 1.10,   # Monday
    1: 1.20,
    2: 1.15,
    3: 1.05,
    4: 0.95,
    5: 0.30,
    6: 0.10
}

# =========================================================
# DTC WEEKDAY MULTIPLIERS
# =========================================================

DTC_WEEKDAY = {
    0: 0.90,
    1: 0.90,
    2: 0.95,
    3: 1.00,
    4: 1.15,
    5: 1.40,
    6: 1.30
}

# =========================================================
# PRODUCT CATEGORY DEMAND
# =========================================================

CATEGORY_WEIGHTS = {
    "Trail": 28,
    "Cross Country": 18,
    "Downcountry": 14,
    "Aggressive Trail": 16,
    "Enduro": 14,
    "Gravel": 8,
    "eMTB": 2
}

# =========================================================
# CUSTOMER ORDER WEIGHTS
# =========================================================

CUSTOMER_WEIGHTS = {
    "Platinum": 12,
    "Gold": 8,
    "Silver": 4,
    "Bronze": 2,
    "DTC": 1
}

# =========================================================
# COST PERCENTAGES
# =========================================================

STANDARD_COST = {
    "Cross Country": 0.53,
    "Downcountry": 0.55,
    "Trail": 0.56,
    "Aggressive Trail": 0.58,
    "Enduro": 0.60,
    "eMTB": 0.64,
    "Gravel": 0.52
}

# =========================================================
# PROMOTIONS
# =========================================================

PROMOTIONS = {
    # Example:
    # "2023-11-24": 2.20,
}

# =========================================================
# WEATHER IMPACT
# =========================================================

WEATHER_MULTIPLIER = {
    "Sunny": 1.05,
    "Cloudy": 1.00,
    "Rain": 0.80,
    "Snow": 0.60
}

# =========================================================
# RANDOM DEMAND NOISE
# =========================================================

NOISE_MEAN = 1.00
NOISE_STD_DEV = 0.08

# =========================================================
# DEALER ORDER PARAMETERS
# =========================================================

MIN_DEALER_LINES = 2
MAX_DEALER_LINES = 6

MIN_DEALER_QTY = 1
MAX_DEALER_QTY = 5

# =========================================================
# DTC ORDER PARAMETERS
# =========================================================

DTC_QTY_WEIGHTS = {
    1: 0.95,
    2: 0.05
}

# =========================================================
# INVENTORY
# =========================================================

TARGET_WEEKS_OF_SUPPLY = 12

REORDER_POINT_WEEKS = 6

LEAD_TIME_DAYS = 90

DEALER = "Dealer"
DTC = "DTC"
