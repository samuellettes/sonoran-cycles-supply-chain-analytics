# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
from datetime import datetime

from simulation.simulation import Simulation
from simulation.demand_engine import preview_day
import simulation.simulation_config as config

# %%
from simulation.simulation import Simulation
from simulation.customer_engine import add_customer_order_weights, select_dealer, select_dtc_customer
from simulation.product_engine import choose_product

# %%
sim = Simulation()
sim.load_master_data()
sim.initialize_inventory()

sim.customers = add_customer_order_weights(sim.customers)

# %%
from datetime import datetime
import pandas as pd

from simulation.simulation import Simulation
from simulation.customer_engine import add_customer_order_weights
from simulation.order_generator import (
    generate_dealer_order,
    generate_dtc_order,
    generate_daily_orders,
)

# %%
sim = Simulation()
sim.load_master_data()
sim.initialize_inventory()

sim.customers = add_customer_order_weights(sim.customers)

# %%
dealer_header, dealer_lines = generate_dealer_order(
    sim,
    datetime(2023, 5, 15),
)

dealer_header
# Out:
# {'sales_order_id': 'SO100000',
#  'order_date': '2023-05-15',
#  'customer_id': 'C0002',
#  'customer_name': 'Desert Trail Bikes',
#  'sales_channel': 'Dealer',
#  'order_status': 'Booked',
#  'payment_terms': 'Net 45',
#  'warehouse': 'Phoenix Distribution Center',
#  'order_total': 14265.1}

# %%
pd.DataFrame(dealer_lines)
# Out:
#   sales_order_id  line_number  product_id             sku model_name category  \
# 0       SO100000            1        1073  SON-SAB-C-M-IR     Sabino    Trail
# 1       SO100000            2        1082  SON-SAB-C-L-GR     Sabino    Trail
# 2       SO100000            3        1138  SON-ORA-C-M-SK     Oracle   Enduro
# 3       SO100000            4        1080  SON-SAB-C-L-SG     Sabino    Trail
#
#   size     color  requested_qty  fulfilled_qty  ...  unit_msrp  discount_pct  \
# 0    M  Ironwood              1              1  ...     4599.0          0.42
# 1    L   Granite              2              2  ...     4599.0          0.42
# 2    M       Sky              1              1  ...     6199.0          0.42
# 3    L   Saguaro              1              1  ...     4599.0          0.42
#
#    unit_price  extended_price  fulfilled_revenue  unit_cost  extended_cost  \
# 0     2667.42         2667.42            2667.42    2575.44        2575.44
# 1     2667.42         5334.84            5334.84    2575.44        5150.88
# 2     3595.42         3595.42            3595.42    3719.40        3719.40
# 3     2667.42         2667.42            2667.42    2575.44        2575.44
#
#    fulfilled_cost  gross_profit  fulfilled_gross_profit
# 0         2575.44         91.98                   91.98
# 1         5150.88        183.96                  183.96
# 2         3719.40       -123.98                 -123.98
# 3         2575.44         91.98                   91.98
#
# [4 rows x 22 columns]

# %%
dtc_header, dtc_lines = generate_dtc_order(
    sim,
    datetime(2023, 5, 15),
)

dtc_header
# Out:
# {'sales_order_id': 'SO100001',
#  'order_date': '2023-05-15',
#  'customer_id': 'C0001',
#  'customer_name': 'Sonoran Cycles Online',
#  'sales_channel': 'DTC',
#  'order_status': 'Booked',
#  'payment_terms': 'Credit Card',
#  'warehouse': 'Phoenix Distribution Center',
#  'order_total': 3299.0}

# %%
pd.DataFrame(dtc_lines)
# Out:
#   sales_order_id  line_number  product_id             sku model_name  \
# 0       SO100001            1        1020  SON-CAT-C-L-SG   Catalina
#
#         category size    color  requested_qty  fulfilled_qty  ...  unit_msrp  \
# 0  Cross Country    L  Saguaro              1              1  ...     3299.0
#
#    discount_pct  unit_price  extended_price  fulfilled_revenue  unit_cost  \
# 0           0.0      3299.0          3299.0             3299.0    1748.47
#
#    extended_cost  fulfilled_cost  gross_profit  fulfilled_gross_profit
# 0        1748.47         1748.47       1550.53                 1550.53
#
# [1 rows x 22 columns]

# %%
daily_summary = generate_daily_orders(
    sim,
    datetime(2023, 5, 15),
    "Sunny",
)

daily_summary
# Out:
# {'date': '2023-05-15',
#  'weather': 'Sunny',
#  'dealer_orders': 26,
#  'dtc_orders': 13,
#  'total_orders': 39}

# %%
pd.DataFrame(sim.sales_orders).head()
# Out:
#   sales_order_id  order_date customer_id          customer_name sales_channel  \
# 0       SO100000  2023-05-15       C0002     Desert Trail Bikes        Dealer
# 1       SO100001  2023-05-15       C0001  Sonoran Cycles Online           DTC
# 2       SO100002  2023-05-15       C0002     Desert Trail Bikes        Dealer
# 3       SO100003  2023-05-15       C0027    Prairie Trail Bikes        Dealer
# 4       SO100004  2023-05-15       C0013    Pacific Trail Bikes        Dealer
#
#   order_status payment_terms                    warehouse  order_total
# 0       Booked        Net 45  Phoenix Distribution Center     14265.10
# 1       Booked   Credit Card  Phoenix Distribution Center      3299.00
# 2       Booked        Net 45  Phoenix Distribution Center     27370.20
# 3       Booked        Net 30  Phoenix Distribution Center     27647.04
# 4       Booked        Net 45  Phoenix Distribution Center     48537.30

# %%
pd.DataFrame(sim.sales_order_lines).head()
# Out:
#   sales_order_id  line_number  product_id             sku model_name  \
# 0       SO100000            1        1073  SON-SAB-C-M-IR     Sabino
# 1       SO100000            2        1082  SON-SAB-C-L-GR     Sabino
# 2       SO100000            3        1138  SON-ORA-C-M-SK     Oracle
# 3       SO100000            4        1080  SON-SAB-C-L-SG     Sabino
# 4       SO100001            1        1020  SON-CAT-C-L-SG   Catalina
#
#         category size     color  requested_qty  fulfilled_qty  ...  unit_msrp  \
# 0          Trail    M  Ironwood              1              1  ...     4599.0
# 1          Trail    L   Granite              2              2  ...     4599.0
# 2         Enduro    M       Sky              1              1  ...     6199.0
# 3          Trail    L   Saguaro              1              1  ...     4599.0
# 4  Cross Country    L   Saguaro              1              1  ...     3299.0
#
#    discount_pct  unit_price  extended_price  fulfilled_revenue  unit_cost  \
# 0          0.42     2667.42         2667.42            2667.42    2575.44
# 1          0.42     2667.42         5334.84            5334.84    2575.44
# 2          0.42     3595.42         3595.42            3595.42    3719.40
# 3          0.42     2667.42         2667.42            2667.42    2575.44
# 4          0.00     3299.00         3299.00            3299.00    1748.47
#
#    extended_cost  fulfilled_cost  gross_profit  fulfilled_gross_profit
# 0        2575.44         2575.44         91.98                   91.98
# 1        5150.88         5150.88        183.96                  183.96
# 2        3719.40         3719.40       -123.98                 -123.98
# 3        2575.44         2575.44         91.98                   91.98
# 4        1748.47         1748.47       1550.53                 1550.53
#
# [5 rows x 22 columns]

# %%
print("Sales orders:", len(sim.sales_orders))
print("Sales order lines:", len(sim.sales_order_lines))
# Out:
# Sales orders: 41
# Sales order lines: 125

# %%
import pandas as pd

from simulation.simulation import Simulation
from simulation.simulation_runner import run_sales_simulation

# %%
sim = Simulation()
sim.load_master_data()
sim.initialize_inventory()

# %%
daily_summary = run_sales_simulation(
    sim,
    start_date="2023-05-01",
    end_date="2023-05-07",
)

# %%
pd.DataFrame(daily_summary)
# Out:
#          date weather  dealer_orders  dtc_orders  total_orders  \
# 0  2023-05-01   Sunny             30          13            43
# 1  2023-05-02   Sunny             32          13            45
# 2  2023-05-03   Sunny             28          13            41
# 3  2023-05-04   Sunny             26          13            39
# 4  2023-05-05   Sunny             25          18            43
# 5  2023-05-06   Sunny              7          23            30
# 6  2023-05-07   Sunny              2          18            20
#
#    total_on_hand_units  total_available_units  out_of_stock_skus
# 0                 8154                   8154                  0
# 1                 7860                   7860                  0
# 2                 7614                   7614                  0
# 3                 7353                   7353                  0
# 4                 7104                   7104                  0
# 5                 7015                   7015                  0
# 6                 6974                   6974                  0

# %%
pd.DataFrame(sim.sales_orders).head()
# Out:
#   sales_order_id  order_date customer_id         customer_name sales_channel  \
# 0       SO100000  2023-05-01       C0035     Adirondack Cycles        Dealer
# 1       SO100001  2023-05-01       C0011         Cascade Bikes        Dealer
# 2       SO100002  2023-05-01       C0035     Adirondack Cycles        Dealer
# 3       SO100003  2023-05-01       C0032  Southern Singletrack        Dealer
# 4       SO100004  2023-05-01       C0030     Blue Ridge Cycles        Dealer
#
#   order_status payment_terms                    warehouse  order_total
# 0       Booked        Net 30  Phoenix Distribution Center     14946.75
# 1       Booked        Net 30  Phoenix Distribution Center     30064.42
# 2       Booked        Net 30  Phoenix Distribution Center     17936.10
# 3       Booked        Net 30  Phoenix Distribution Center     17546.10
# 4       Booked        Net 30  Phoenix Distribution Center     29134.42

# %%
pd.DataFrame(sim.sales_order_lines).head()
# Out:
#   sales_order_id  line_number  product_id              sku model_name  \
# 0       SO100000            1        1076   SON-SAB-C-M-GR     Sabino
# 1       SO100000            2        1087  SON-SAB-C-XL-SS     Sabino
# 2       SO100000            3        1073   SON-SAB-C-M-IR     Sabino
# 3       SO100001            1        1107   SON-ROM-C-M-CY     Romero
# 4       SO100001            2        1071   SON-SAB-C-S-CY     Sabino
#
#            category size     color  requested_qty  fulfilled_qty  ...  \
# 0             Trail    M   Granite              3              3  ...
# 1             Trail   XL    Sunset              1              1  ...
# 2             Trail    M  Ironwood              1              1  ...
# 3  Aggressive Trail    M    Coyote              5              5  ...
# 4             Trail    S    Coyote              1              1  ...
#
#    unit_msrp  discount_pct  unit_price  extended_price  fulfilled_revenue  \
# 0     4599.0          0.35     2989.35         8968.05            8968.05
# 1     4599.0          0.35     2989.35         2989.35            2989.35
# 2     4599.0          0.35     2989.35         2989.35            2989.35
# 3     5199.0          0.38     3223.38        16116.90           16116.90
# 4     4599.0          0.38     2851.38         2851.38            2851.38
#
#    unit_cost  extended_cost  fulfilled_cost  gross_profit  \
# 0    2575.44        7726.32         7726.32       1241.73
# 1    2575.44        2575.44         2575.44        413.91
# 2    2575.44        2575.44         2575.44        413.91
# 3    3015.42       15077.10        15077.10       1039.80
# 4    2575.44        2575.44         2575.44        275.94
#
#    fulfilled_gross_profit
# 0                 1241.73
# 1                  413.91
# 2                  413.91
# 3                 1039.80
# 4                  275.94
#
# [5 rows x 22 columns]

# %%
print("Sales orders:", len(sim.sales_orders))
print("Sales order lines:", len(sim.sales_order_lines))
# Out:
# Sales orders: 261
# Sales order lines: 712

# %%
orders_df = pd.DataFrame(sim.sales_orders)
lines_df = pd.DataFrame(sim.sales_order_lines)

header_totals = orders_df.set_index("sales_order_id")["order_total"]
line_totals = lines_df.groupby("sales_order_id")["extended_price"].sum()

max_difference = (
    header_totals.round(2) - line_totals.round(2)
).abs().max()

max_difference
# Out:
# 0.0

# %%
sim = Simulation()
sim.load_master_data()
sim.initialize_inventory()

daily_summary = run_sales_simulation(
    sim,
    start_date="2023-01-01",
    end_date="2023-12-31",
)

print("Sales orders:", len(sim.sales_orders))
print("Sales order lines:", len(sim.sales_order_lines))
# Out:
# Sales orders: 9267
# Sales order lines: 25728

# %%
sim.export_tables()

# %%
orders_df = pd.DataFrame(sim.sales_orders)
lines_df = pd.DataFrame(sim.sales_order_lines)
daily_df = pd.DataFrame(sim.daily_order_summary)

print("Sales orders:", len(orders_df))
print("Sales order lines:", len(lines_df))
print("Daily summaries:", len(daily_df))
print("Total revenue:", round(orders_df["order_total"].sum(), 2))
print("Total units:", lines_df["requested_qty"].sum())
# Out:
# Sales orders: 9267
# Sales order lines: 25728
# Daily summaries: 365
# Total revenue: 165002397.23
# Total units: 51756

# %%
header_totals = orders_df.set_index("sales_order_id")["order_total"]
line_totals = lines_df.groupby("sales_order_id")["extended_price"].sum()

max_difference = (
    header_totals.round(2) - line_totals.round(2)
).abs().max()

max_difference
# Out:
# 0.0

# %%
orders_df["sales_channel"].value_counts()
# Out:
# sales_channel
# Dealer    5383
# DTC       3884
# Name: count, dtype: int64

# %%
orders_df.groupby("sales_channel")["order_total"].sum().round(2)
# Out:
# sales_channel
# DTC       2.097359e+07
# Dealer    1.440288e+08
# Name: order_total, dtype: float64

# %%
lines_df.groupby("model_name")["requested_qty"].sum().sort_values(ascending=False)
# Out:
# model_name
# Sabino        13877
# Romero        12914
# Oracle         8839
# Catalina       7210
# Rincon         3992
# Sky Island     2973
# Sonoita        1951
# Name: requested_qty, dtype: int64

# %%
orders_df["order_date"] = pd.to_datetime(orders_df["order_date"])
orders_df["month"] = orders_df["order_date"].dt.month

monthly_orders = (
    orders_df
    .groupby("month")["sales_order_id"]
    .count()
    .reset_index(name="order_count")
)

monthly_orders
# Out:
#     month  order_count
# 0       1          460
# 1       2          499
# 2       3          772
# 3       4          969
# 4       5         1179
# 5       6         1074
# 6       7          961
# 7       8          856
# 8       9          730
# 9      10          626
# 10     11          649
# 11     12          492

# %%
import pandas as pd

from simulation.simulation import Simulation
from simulation.simulation_runner import run_sales_simulation

# %%
sim = Simulation()
sim.load_master_data()
sim.initialize_inventory()

daily_summary = run_sales_simulation(
    sim,
    start_date="2023-05-01",
    end_date="2023-05-07",
)

# %%
pd.DataFrame(daily_summary)
# Out:
#          date weather  dealer_orders  dtc_orders  total_orders  \
# 0  2023-05-01   Sunny             26          14            40
# 1  2023-05-02   Sunny             29          13            42
# 2  2023-05-03   Sunny             30          15            45
# 3  2023-05-04   Sunny             27          15            42
# 4  2023-05-05   Sunny             26          17            43
# 5  2023-05-06   Sunny              7          19            26
# 6  2023-05-07   Sunny              2          20            22
#
#    total_on_hand_units  total_available_units  out_of_stock_skus
# 0                 8168                   8168                  0
# 1                 7899                   7899                  0
# 2                 7610                   7610                  0
# 3                 7320                   7320                  0
# 4                 7079                   7079                  0
# 5                 6980                   6980                  0
# 6                 6942                   6942                  0

# %%
lines_df = pd.DataFrame(sim.sales_order_lines)

lines_df[
    [
        "sales_order_id",
        "product_id",
        "model_name",
        "requested_qty",
        "fulfilled_qty",
        "backordered_qty",
        "fill_rate",
        "extended_price",
        "fulfilled_revenue",
    ]
].head()
# Out:
#   sales_order_id  product_id model_name  requested_qty  fulfilled_qty  \
# 0       SO100000        1084     Sabino              1              1
# 1       SO100000        1076     Sabino              3              3
# 2       SO100000        1106     Romero              1              1
# 3       SO100000        1021   Catalina              5              5
# 4       SO100001        1043     Rincon              1              1
#
#    backordered_qty  fill_rate  extended_price  fulfilled_revenue
# 0                0        1.0         2851.38            2851.38
# 1                0        1.0         8554.14            8554.14
# 2                0        1.0         3223.38            3223.38
# 3                0        1.0        10226.90           10226.90
# 4                0        1.0         2479.38            2479.38

# %%
inventory_history_df = pd.DataFrame(sim.inventory_history)

inventory_history_df.head()
# Out:
#   snapshot_date  product_id  on_hand  allocated  available
# 0    2023-05-01        1001       40          0         40
# 1    2023-05-01        1002       40          0         40
# 2    2023-05-01        1003       40          0         40
# 3    2023-05-01        1004       40          0         40
# 4    2023-05-01        1005       40          0         40

# %%
print("Sales orders:", len(sim.sales_orders))
print("Sales order lines:", len(sim.sales_order_lines))
print("Inventory history rows:", len(sim.inventory_history))
# Out:
# Sales orders: 260
# Sales order lines: 727
# Inventory history rows: 1470
